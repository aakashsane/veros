# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt

# %%
d=xr.open_dataset('acc.averages.nc')

# %%
d
# Out:
# <xarray.Dataset>
# Dimensions:       (xt: 30, xu: 30, yt: 42, yu: 42, zt: 15, zw: 15, tensor1: 2,
#                    tensor2: 2, isle: 2, Time: 32)
# Coordinates:
#   * xt            (xt) float64 -1.0 1.0 3.0 5.0 7.0 ... 49.0 51.0 53.0 55.0 57.0
#   * xu            (xu) float64 0.0 2.0 4.0 6.0 8.0 ... 50.0 52.0 54.0 56.0 58.0
#   * yt            (yt) float64 -41.0 -39.0 -37.0 -35.0 ... 35.0 37.0 39.0 41.0
#   * yu            (yu) float64 -40.0 -38.0 -36.0 -34.0 ... 36.0 38.0 40.0 42.0
#   * zt            (zt) float64 -1.942e+03 -1.666e+03 -1.43e+03 ... -26.0 -14.0
#   * zw            (zw) float64 -1.804e+03 -1.548e+03 -1.312e+03 ... -20.0 0.0
#   * tensor1       (tensor1) float64 0.0 1.0
#   * tensor2       (tensor2) float64 0.0 1.0
#   * isle          (isle) float64 0.0 1.0
#   * Time          (Time) timedelta64[ns] 10 days 20 days ... 310 days 320 days
# Data variables:
#     salt          (Time, zt, yt, xt) float64 ...
#     temp          (Time, zt, yt, xt) float64 ...
# ...

# %%
d['u'].shape
# Out:
# (32, 15, 42, 30)

# %%
i=30
d['temp'][i,14,:,:].plot()

# %%
np.array(
            [50.0, 70.0, 100.0, 140.0, 190.0, 240.0, 290.0, 340.0, 390.0, 440.0, 490.0, 540.0, 590.0, 640.0, 690.0]
        )

# %%
np.linspace(50,700,30)
# Out:
# array([ 50.        ,  72.4137931 ,  94.82758621, 117.24137931,
#        139.65517241, 162.06896552, 184.48275862, 206.89655172,
#        229.31034483, 251.72413793, 274.13793103, 296.55172414,
#        318.96551724, 341.37931034, 363.79310345, 386.20689655,
#        408.62068966, 431.03448276, 453.44827586, 475.86206897,
#        498.27586207, 520.68965517, 543.10344828, 565.51724138,
#        587.93103448, 610.34482759, 632.75862069, 655.17241379,
#        677.5862069 , 700.        ])
